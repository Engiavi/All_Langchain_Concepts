# %%
# !pip install langchain chromadb tiktoken pypdf langchain-community langchain_google_genai

# %%
# !pip install -U langchain-chroma

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from langchain_chroma.vectorstores import Chroma
from langchain.schema import Document
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 2
#       1 from langchain_google_genai import GoogleGenerativeAIEmbeddings
# ----> 2 from langchain_chroma.vectorstores import Chroma
#       3 from langchain.schema import Document
#
# ModuleNotFoundError: No module named 'langchain_chroma'

# %%
from langchain.schema import Document
doc1  = Document(
    page_content="This is a test document.",
    metadata={"source": "test_doc1"}
)
doc2 = Document(
    page_content="This is another test document.",
    metadata={"source": "test_doc2"}
)
doc3 = Document(
    page_content="This is a third test document.",
    metadata={"source": "test_doc3"}
)

# %%
docs = [doc1, doc2, doc3]

# %%
embeddings = GoogleGenerativeAIEmbeddings(model="models/text-embedding-004")
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 embeddings = GoogleGenerativeAIEmbeddings(model="models/text-embedding-004")
#
#     [... skipping hidden 1 frame]
#
# File c:\Users\91798\anaconda3\Lib\site-packages\langchain_google_genai\embeddings.py:95, in GoogleGenerativeAIEmbeddings.validate_environment(self)
#      92     google_api_key = self.google_api_key
#      93 client_info = get_client_info("GoogleGenerativeAIEmbeddings")
# ---> 95 self.client = build_generative_service(
#      96     credentials=self.credentials,
#      97     api_key=google_api_key,
#      98     client_info=client_info,
#      99     client_options=self.client_options,
#     100 )
#     101 return self
#
# ...

# %%
vector_stores =chroma()
